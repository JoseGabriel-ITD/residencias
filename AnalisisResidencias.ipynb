# %%
import pandas as pd
import numpy as np

#data = pd.read_csv("C://temp/FormularioResidenciasAGO-DIC-2018.csv", encoding="ANSI")
data = pd.read_csv("C://temp/FormularioResidencias.csv", encoding="UTF-8")

# %%
data.head()
# Out:
#        MarcaTemporal                       Residente     Genero  \
# 0  3/3/2020 10:14:44           Daniel Alvarez Lares   Masculino
# 1  3/3/2020 10:31:29    Alondra Yareli Ramos Flores    Femenino
# 2  3/3/2020 10:33:10    Ana Victoria Santos Palacios   Femenino
# 3  3/3/2020 10:43:54     Favela Gonzalez José Damaso  Masculino
# 4  3/3/2020 10:55:10  Hector Guillermo Avitia Rivera  Masculino
#
#                                   Carrera      PeriodoResidencia  \
# 0  Ingenieria en Sistemas Computacionales  Agosto-Diciembre 2018
# 1  Ingenieria en Sistemas Computacionales  Agosto-Diciembre 2018
# 2  Ingenieria en Sistemas Computacionales  Agosto-Diciembre 2018
# 3  Ingenieria en Sistemas Computacionales  Agosto-Diciembre 2018
# 4  Ingenieria en Sistemas Computacionales  Agosto-Diciembre 2018
#
#                   RevisorProyecto  \
# 0     Gabriel Arturo Lugo Morales
# 1     José Roberto López Quiñonez
# 2     José Roberto López Quiñonez
# 3  Marco Antonio Rodriguez Zúñiga
# 4  Marco Antonio Rodriguez Zúñiga
#
#                                             Proyecto  \
# 0  NUmero de identificación único para componente...
# 1  Documentación técnica y generación de pruebas ...
# 2  Documentación técnica y generación de pruebas ...
# 3  Documentación de la infraestructura de red del...
# 4  Reestructuración de la infraestructura de red ...
#
#                                   EmpresaInstitucion  \
# 0      Erae Automotive Systems México S de R.L de CV
# 1  SIITECS Soluciones Integrales e InnovaciónTecn...
# 2  SIITECS Soluciones Integrales e InnovaciónTecn...
# 3                   Instituto Tecnológico de Durango
# 4                   Instituto Tecnológico de Durango
#
#                                             Objetivo   Sector  \
# 0  Diseñar y desarrollar un sistema computacional...  Privado
# 1  Apoyar a la empresa SIITECS en la elaboración ...  Privado
# 2  Apoyar a la empresa SIITECS en la elaboración ...  Privado
# 3  Documentar el estado actual de la red del Inst...  Privado
# 4  Desarrollar una propuesta para el rediseño de ...  Público
#
#                              OrigenProyecto  \
# 0  Iniciativa propia (propuesta del alumno)
# 1  Iniciativa propia (propuesta del alumno)
# 2  Iniciativa propia (propuesta del alumno)
# 3  Iniciativa propia (propuesta del alumno)
# 4  Iniciativa propia (propuesta del alumno)
#
#                                  AlcanceTipoProyecto   Region        Estado  \
# 0                        Desarrollo nuevo desde cero  Foraneo  Nuevo León\n
# 1  Mantenimiento, mejoras, adecuaciones de lo ya ...    Local       Durango
# 2  Mantenimiento, mejoras, adecuaciones de lo ya ...    Local       Durango
# 3                        Desarrollo nuevo desde cero    Local       Durango
# 4  Mantenimiento, mejoras, adecuaciones de lo ya ...    Local       Durango
#
#           AreaConocimiento AlumnosAsignados LenguajesProgramacion BasesDatos  \
# 0             Sistema Java       Individual                  Java      MySQL
# 1  Documentacion y pruebas                2             No aplica  No aplica
# 2  Documnetación y pruebas                2             No aplica  No aplica
# 3     Documentación de red       Individual             No aplica  No aplica
# 4                    Redes                2             No aplica  No aplica
#
#   EntornoDesarrollo FrameworksDesarrollo
# 0          Netbeans            No aplica
# 1         No Aplica            No aplica
# 2         No Aplica            No aplica
# 3         No Aplica            No aplica
# 4         No Aplica            No aplica

# %%
## Seleccionar coliumnas
carreras = data.iloc[ : , [1,5,6,7,8,13 ] ]

carreras.head(3)
# Out:
#            Nombre del residente         Revisor del proyecto  \
# 0         Daniel Alvarez Lares   Gabriel Arturo Lugo Morales
# 1  Alondra Yareli Ramos Flores   José Roberto López Quiñonez
# 2  Ana Victoria Santos Palacios  José Roberto López Quiñonez
#
#                                  Nombre del proyecto  \
# 0  NUmero de identificación único para componente...
# 1  Documentación técnica y generación de pruebas ...
# 2  Documentación técnica y generación de pruebas ...
#
#                                Empresa o Institucion  \
# 0      Erae Automotive Systems México S de R.L de CV
# 1  SIITECS Soluciones Integrales e InnovaciónTecn...
# 2  SIITECS Soluciones Integrales e InnovaciónTecn...
#
#                                             Objetivo        Estado
# 0  Diseñar y desarrollar un sistema computacional...  Nuevo León\n
# 1  Apoyar a la empresa SIITECS en la elaboración ...       Durango
# 2  Apoyar a la empresa SIITECS en la elaboración ...       Durango

# %%
data['Carrera'].unique()
# Out:
# array(['Ingenieria en Sistemas Computacionales', 'Ingenieria Informatica',
#        'Ingenieria en Tecnologías de Informacion'], dtype=object)

# %%
objetivos = data.iloc[ : , 8 ]

objetivos.head()
# Out:
# 0    Diseñar y desarrollar un sistema computacional...
# 1    Apoyar a la empresa SIITECS en la elaboración ...
# 2    Apoyar a la empresa SIITECS en la elaboración ...
# 3    Documentar el estado actual de la red del Inst...
# 4    Desarrollar una propuesta para el rediseño de ...
# Name: Objetivo, dtype: object

# %%
import pandas as pd
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import warnings 
warnings.filterwarnings('ignore')

# %%
def plot_wordcloud(text, mask=None, max_words=40, max_font_size=70, figure_size=(24.0,16.0), 
                   title = None, title_size=40, image_color=False):
    stopwords = set(STOPWORDS)
    more_stopwords = {'de', 'para', 'un', 'las', 'en', 'con', 'el', 'la', 'una','que', 'del', 'los'}
    stopwords = stopwords.union(more_stopwords)

    wordcloud = WordCloud(background_color='white',
                    stopwords = stopwords,
                    max_words = max_words,
                    max_font_size = max_font_size, 
                    random_state = 42,
                    contour_width=1, 
                    contour_color='firebrick',
                    mask = mask)
    wordcloud.generate(text)
    
    plt.figure(figsize=figure_size)
    if image_color:
        image_colors = ImageColorGenerator(mask);
        plt.imshow(wordcloud.recolor(color_func=image_colors), interpolation="bilinear");
        plt.title(title, fontdict={'size': title_size,  
                                  'verticalalignment': 'bottom'})
    else:
        plt.imshow(wordcloud);
        plt.title(title, fontdict={'size': title_size, 'color': 'green', 
                                  'verticalalignment': 'bottom'})
    plt.axis('off');
    plt.tight_layout()  
    
d = 'C://temp/'

# %%
comments_text = str(objetivos)
##comments_mask = np.array(Image.open(d + 'comment.png'))
comments_mask = np.array(Image.open(d + 'birrete.png'))
plot_wordcloud(comments_text, comments_mask, max_words=40, max_font_size=200, 
               title = 'Palabras mas usadas en Objetivos', title_size=50, )

# %%
comments_text = str(objetivos)
##comments_mask = np.array(Image.open(d + 'comment.png'))
comments_mask = np.array(Image.open(d + 'upvote2.png'))
plot_wordcloud(comments_text, comments_mask, max_words=40, max_font_size=200, 
               title = 'Palabras mas usadas en Objetivos', title_size=50, )

# %%
comments_text = str(objetivos)
##comments_mask = np.array(Image.open(d + 'comment.png'))
comments_mask = np.array(Image.open(d + 'ninacompu.png'))
plot_wordcloud(comments_text, comments_mask, max_words=40, max_font_size=200, 
               title = 'Palabras mas usadas en Objetivos', title_size=50, )

# %%
import pandas as pd
import numpy as np

#data = pd.read_csv("C://temp/FormularioResidenciasAGO-DIC-2018.csv", encoding="ANSI")
data = pd.read_csv("C://temp/FormularioResidencias_2.csv", encoding="UTF-8")

# %%
objetivos = data.iloc[ : , 8 ]

objetivos.head()
# Out:
# 0    Diseñar y desarrollar un sistema computacional...
# 1    Apoyar a la empresa SIITECS en la elaboración ...
# 2    Apoyar a la empresa SIITECS en la elaboración ...
# 3    Documentar el estado actual de la red del Inst...
# 4    Desarrollar una propuesta para el rediseño de ...
# Name: Objetivo, dtype: object

# %%
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import warnings 
warnings.filterwarnings('ignore')

# %%
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import warnings 
warnings.filterwarnings('ignore')

# %%
comments_text = str(objetivos)
##comments_mask = np.array(Image.open(d + 'comment.png'))
comments_mask = np.array(Image.open(d + 'birrete.png'))
plot_wordcloud(comments_text, comments_mask, max_words=50, max_font_size=200, 
               title = 'Palabras mas usadas en Objetivos', title_size=50, )

# %%
len(data.index)
# Out:
# 122

# %%
comments_text = str(objetivos)
##comments_mask = np.array(Image.open(d + 'comment.png'))
comments_mask = np.array(Image.open(d + 'ninacompu.png'))
plot_wordcloud(comments_text, comments_mask, max_words=50, max_font_size=150, 
               title = 'Palabras mas usadas en Objetivos', title_size=50, )

# %%
comments_text = str(objetivos)
##comments_mask = np.array(Image.open(d + 'comment.png'))
comments_mask = np.array(Image.open(d + 'ninacompu.png'))
plot_wordcloud(comments_text, comments_mask, max_words=300, max_font_size=200, 
               title = 'Palabras mas usadas en Objetivos', title_size=50, )

# %%
comments_text = str(objetivos)
##comments_mask = np.array(Image.open(d + 'comment.png'))
comments_mask = np.array(Image.open(d + 'birrete.png'))
plot_wordcloud(comments_text, comments_mask, max_words=300, max_font_size=150, 
               title = 'Palabras mas usadas en Objetivos', title_size=50, )

# %%
def plot_wordcloud2(text, mask=None, max_words=40, max_font_size=70, figure_size=(24.0,16.0), 
                   title = None, title_size=40, image_color=False):
    stopwords = set(STOPWORDS)
    more_stopwords = {'de', 'para', 'un', 'las', 'en', 'con', 'el', 'la', 'una','que', 'del', 'los'}
    stopwords = stopwords.union(more_stopwords)

    wordcloud = WordCloud(background_color='white',
                    stopwords = stopwords,
                    max_words = max_words,
                    max_font_size = max_font_size, 
                    random_state = 42,
                    mask = mask)
    wordcloud.generate(text)
    
    plt.figure(figsize=figure_size)
    if image_color:
        image_colors = ImageColorGenerator(mask);
        plt.imshow(wordcloud.recolor(color_func=image_colors), interpolation="bilinear");
        plt.title(title, fontdict={'size': title_size,  
                                  'verticalalignment': 'bottom'})
    else:
        plt.imshow(wordcloud);
        plt.title(title, fontdict={'size': title_size, 'color': 'green', 
                                  'verticalalignment': 'bottom'})
    plt.axis('off');
    plt.tight_layout()  
    
d = 'C://temp/'

# %%
comments_text = str(objetivos)
##comments_mask = np.array(Image.open(d + 'comment.png'))
comments_mask = np.array(Image.open(d + 'birrete.png'))
plot_wordcloud2(comments_text, comments_mask, max_words=150, max_font_size=150, 
               title = 'Palabras mas usadas en Objetivos', title_size=50, )

# %%
comments_text = str(objetivos)
##comments_mask = np.array(Image.open(d + 'comment.png'))
comments_mask = np.array(Image.open(d + 'ninacompu.png'))
plot_wordcloud2(comments_text, comments_mask, max_words=500, max_font_size=200, 
               title = 'Palabras mas usadas en Objetivos', title_size=50, )
